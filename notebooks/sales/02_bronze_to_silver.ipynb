# %% [markdown]
# # Sales: Bronze -> Silver
#
# Drop bad rows, normalize types and text.

# %%
# %run ../00_config.ipynb
# %run ../00_utils.ipynb
# Out:
# /usr/local/lib/python3.12/site-packages/nbformat/validator.py:434: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   _validate(nbdict, ref, version, version_minor, relax_add_props)
# [08/23/26 15:10:27] INFO     Using                                                                  ]8;id=2718186;file:///usr/local/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=2718187;file:///usr/local/lib/python3.12/site-packages/kedro/framework/project/__init__.py#302\302]8;;\
#                              '/usr/local/lib/python3.12/site-packages/kedro/framework/project/rich_
#                              logging.yml' as logging configuration.
# ...

# %%
bronze_sales = catalog.load("bronze_sales")
bronze_sales
# Out:
#                     INFO     Loading data from bronze_sales (CSVDataset)...                    ]8;id=2718216;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=2718217;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py#1050\1050]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    order_id customer_name  product  quantity  unit_price  order_date  \
# 0       1.0    Acme Corp    Widget        10        25.5  2023-01-15
# 1       2.0    Globex Inc   GADGET         5        12.0  2023-02-20
# 2       3.0   Initech LLC   Widget        20        25.5  2023-03-05
# 3       NaN       Bad Row  Unknown         0         0.0  2022-01-01
# 4       4.0  Umbrella Co     gizmo         8        40.0  2023-04-10
#
#                          notes
# 0                     priority
# 1                          NaN
# ...

# %%
import pandas as pd

silver_sales = bronze_sales.dropna(subset=["order_id"]).copy()
silver_sales["order_id"] = silver_sales["order_id"].astype(int)
silver_sales["customer_name"] = clean_text(silver_sales["customer_name"])
silver_sales["product"] = clean_text(silver_sales["product"]).str.lower()
silver_sales["order_date"] = pd.to_datetime(silver_sales["order_date"]).dt.date
silver_sales
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    order_id customer_name product  quantity  unit_price  order_date  \
# 0         1     Acme Corp  widget        10        25.5  2023-01-15
# 1         2    Globex Inc  gadget         5        12.0  2023-02-20
# 2         3   Initech LLC  widget        20        25.5  2023-03-05
# 4         4   Umbrella Co   gizmo         8        40.0  2023-04-10
#
#         notes
# 0    priority
# 1         NaN
# 2  bulk order
# 4         NaN

# %%
catalog.save("silver_sales", silver_sales)
# Out:
#                     INFO     Saving data to silver_sales (CSVDataset)...                       ]8;id=2718223;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=2718224;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py#1006\1006]8;;\

# %% [markdown]
# ## PySpark alternative (reference only)
#
# PySpark isn't installed in this image. Left commented out to show how this
# stage would transform with Spark instead of pandas.

# %%
# from pyspark.sql.functions import col, lower, to_date, trim
#
# bronze_sales_spark = (
#     spark.read.option("header", "true")
#     .csv(str(PROJECT_ROOT / "data/02_bronze/sales.csv"))
# )
#
# silver_sales_spark = (
#     bronze_sales_spark
#     .filter(col("order_id").isNotNull())
#     .withColumn("order_id", col("order_id").cast("int"))
#     .withColumn("customer_name", trim(col("customer_name")))
#     .withColumn("product", lower(trim(col("product"))))
#     .withColumn("order_date", to_date(col("order_date")))
# )
#
# silver_sales_spark.write.mode("overwrite").option("header", "true").csv(
#     str(PROJECT_ROOT / "data/03_silver/sales.csv")
# )
