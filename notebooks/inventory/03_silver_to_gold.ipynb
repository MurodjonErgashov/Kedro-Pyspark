# %% [markdown]
# # Inventory: Silver -> Gold
#
# Keep only the columns downstream consumers need.

# %%
# %run ../00_config.ipynb
# Out:
# /usr/local/lib/python3.12/site-packages/nbformat/validator.py:434: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   _validate(nbdict, ref, version, version_minor, relax_add_props)
# [08/23/26 15:06:03] INFO     Using                                                                  ]8;id=15505228;file:///usr/local/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=15505229;file:///usr/local/lib/python3.12/site-packages/kedro/framework/project/__init__.py#302\302]8;;\
#                              '/usr/local/lib/python3.12/site-packages/kedro/framework/project/rich_
#                              logging.yml' as logging configuration.
# ...

# %%
silver_inventory = catalog.load("silver_inventory")
silver_inventory
# Out:
#                     INFO     Loading data from silver_inventory (CSVDataset)...                ]8;id=15505252;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=15505253;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py#1050\1050]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    item_id      item_name    category  stock_count warehouse last_updated  \
# 0      201     Steel Bolt    hardware          500      WH-1   2023-01-10
# 1      202    Copper Wire  electrical          150      WH-2   2023-02-15
# 2      203  Rubber Gasket    hardware          300      WH-1   2023-03-01
# 3      204       LED Bulb  electrical         1000      WH-3   2023-04-20
#
#        notes
# 0  restocked
# 1        NaN
# 2  low stock
# 3        NaN

# %%
gold_inventory = silver_inventory[INVENTORY_GOLD_COLUMNS]
gold_inventory
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    item_id      item_name    category  stock_count warehouse last_updated
# 0      201     Steel Bolt    hardware          500      WH-1   2023-01-10
# 1      202    Copper Wire  electrical          150      WH-2   2023-02-15
# 2      203  Rubber Gasket    hardware          300      WH-1   2023-03-01
# 3      204       LED Bulb  electrical         1000      WH-3   2023-04-20

# %%
catalog.save("gold_inventory", gold_inventory)
# Out:
#                     INFO     Saving data to gold_inventory (CSVDataset)...                     ]8;id=15505259;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=15505260;file:///usr/local/lib/python3.12/site-packages/kedro/io/data_catalog.py#1006\1006]8;;\

# %% [markdown]
# ## PySpark alternative (reference only)
#
# PySpark isn't installed in this image. Left commented out to show how this
# stage would select/write with Spark instead of pandas.

# %%
# silver_inventory_spark = (
#     spark.read.option("header", "true")
#     .csv(str(PROJECT_ROOT / "data/03_silver/inventory.csv"))
# )
#
# gold_inventory_spark = silver_inventory_spark.select(*INVENTORY_GOLD_COLUMNS)
#
# gold_inventory_spark.write.mode("overwrite").option("header", "true").csv(
#     str(PROJECT_ROOT / "data/04_gold/inventory.csv")
# )
